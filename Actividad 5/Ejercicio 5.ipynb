# %% [markdown]
# # Ejercicio 5
#
# -How can you modify the units of the figures?
# -Check the examples at https://seaborn.pydata.org/ and create your own figures. If possible, use your own data.

# %%
def import_csv(file):
    # Read the file into a DataFrame: df
    import pandas as pd
    return pd.read_csv(file)

# %%
# Import the file
path= "C:\\Users\\ebert\\OneDrive - Universidad Autónoma del Carmen\\Curso de Ciencia de Datos\\Curso de Python\\Bases de datos\\Terminos_lagoon_TA_DIC_2023_RawData.csv"
df = import_csv(path)

# %%
print(df.columns)
# Out:
# Index(['sample', 'date', 'estuary', 'area', 'station', 'layer_depth', 'season',
#        'chlorophy_microg_l', 'cond_microsiemens_cm', 'depth_m',
#        'do_percent_sat', 'do_mg_l', 'sal_psu', 'sp_cond_microsiemens_cm',
#        'turbidity_fnu', 'temp_c', 'latitude', 'longitude', 'dic_micromol_kg',
#        'ta_micromol_kg', 'dummy_data'],
#       dtype='object')

# %%
sns.relplot(
    data=df,
    x='ta_micromol_kg',
    y='dic_micromol_kg',
    hue='season',
    palette='viridis',
    height=5,        # altura de cada subgráfico (en pulgadas)
    aspect=1.5,       # relación ancho/alto (width = height × aspect),
    kind='scatter' 
)
plt.show()
